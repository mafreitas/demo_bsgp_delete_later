# %% [markdown]
# # Mike's Awesome Hello World Python Notebook

# %% [markdown]
# ## This is my first jupyter notebook

# %% [markdown]
# I am just showing off for the *class*

# %%
print("Hello World")
# Out:
# Hello World
